# %% [markdown]
# ## 1. Установка пакета и основные возможности

# %% [markdown]
# Библиотека **matplotlib** предназначена для построения графиков

# %% [markdown]
# Для того, чтобы графики выводились прямо в **jupyter**, без открытия дополнительного окна используем следующую команду:

# %%
# %matplotlib inline

# %% [markdown]
# Импорт основного модуля **pyplot** из библотеки **matplotlib** производится следующим образом:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Основная функция данного модуля - **plot**

# %%
plt.plot([1, 2, 10, 4, 5])

# %% [markdown]
# ### Компоненты графика

# %% [markdown]
# ![](https://proproprogs.ru/htm/modules/files/matplotlib-funkciya-plot-dlya-postroeniya-i-oformleniya-dvumernyh-grafikov.files/image006.jpg)

# %% [markdown]
# ### Основные типы графиков в библиотеке matplotlib

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213342.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213342.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213359.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213359.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213415.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213415.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213430.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20213430.png)

# %% [markdown]
# ## 2. Функция plot для построения и оформления двумерных графиков

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Функция **plot** отображает обычные двумерные графики

# %%
plt.plot([1, -2, 4, 1])

# %% [markdown]
# По оси **Y** отображаются значения из переданного списка, а по оси **X** - индекс, так работает график по умолчанию

# %% [markdown]
# Под капотом функции список меняет тип данных на numpy массив

# %% [markdown]
# Функция **plot** может принимать данные по оси **X**, так и по оси **Y** с помощью аргументов

# %%
x = np.array([3, 5, 7, 9])
y = np.array([1, 15, 6, 10])

# %%
plt.plot(x, y)

# %% [markdown]
# В **jupyter notebook** все вызываемые функции необходмо использовать в одной строке, тогда график будет построен правильно и последовательно

# %%
x1 = np.array([i + 1 for i in x])
y1 = np.array([i + i for i in y])

# %% [markdown]
# Иногда необходимо наложить графики друг на друга, достаточно передать нужные аргументы, при это кол-во точек в массивах может быть разное

# %%
plt.plot(x, y, x1, y1) # наложение графиков друг на друга
plt.grid() # отображение сетки

# %% [markdown]
# Ещё один способ построения такого же графика:

# %%
plt.plot(x, y)
plt.plot(x1, y1)
plt.grid()

# %% [markdown]
# ### Изменение стилей линий у графиков

# %% [markdown]
# Тип линий можно поменять с помощью **3-го параметра**

# %%
plt.plot(x, y, '--')

# %% [markdown]
# **Типы линий:**

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20220923.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20220923.png)

# %% [markdown]
# ### Изменение цвета линий графиков

# %% [markdown]
# Цвета линий также меняются с помощью параметров

# %%
plt.plot(x, y, 'b', x1, y1, 'r') # параметр является буквой

# %%
plt.plot(x, y, 'b:', x1, y1, 'r-.') # параметр является буквой с типом линии

# %% [markdown]
# Можно явно указать параметр **color** для сразу всех графиков

# %%
plt.plot(x, y, x1, y1, color='Orange')

# %% [markdown]
# Преимущество данного параметра, то что можно задавать разные цветовые схемы, типа RGB и т.д.

# %%
plt.plot(x, y, x1, y1, color=(0.30, 0.20, 0.90, 0.5)) # 4 цифра это степень прозрачности

# %% [markdown]
# ### Изменение маркеров точек у графиков

# %% [markdown]
# Существует возможность изменения маркеров у точек

# %%
plt.plot(x, y, 'r-o', x1, y1, 'm:s')

# %% [markdown]
# Другой способ определения маркера – использование параметра **marker**:

# %%
plt.plot(x, y, '-go', x1, y1, 's:m', marker='d')
# Out:
# C:\Users\Vadim\AppData\Local\Temp\ipykernel_10984\3239869785.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-go" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, y, '-go', x1, y1, 's:m', marker='d')
# C:\Users\Vadim\AppData\Local\Temp\ipykernel_10984\3239869785.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s:m" (-> marker='s'). The keyword argument will take precedence.
#   plt.plot(x, y, '-go', x1, y1, 's:m', marker='d')
# ...

# %% [markdown]
# Для задания цвета маркера, отличного от цвета линии, применяется параметр markerfacecolor:

# %%
plt.plot(x, y, '-go', x1, y1, 's:m', marker='D', markerfacecolor='w', linewidth=3)
# Out:
# C:\Users\Vadim\AppData\Local\Temp\ipykernel_10984\1285412466.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-go" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, y, '-go', x1, y1, 's:m', marker='D', markerfacecolor='w', linewidth=3)
# C:\Users\Vadim\AppData\Local\Temp\ipykernel_10984\1285412466.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s:m" (-> marker='s'). The keyword argument will take precedence.
#   plt.plot(x, y, '-go', x1, y1, 's:m', marker='D', markerfacecolor='w', linewidth=3)
# ...

# %% [markdown]
# **Виды маркеров:**

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20223224.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20223224.png)

# %% [markdown]
# ### Именованные параметры функции plot()

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20223849.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-04%20223849.png)

# %% [markdown]
# ### Заливка областей графика

# %% [markdown]
# Наконец, можно делать заливку областей графика с помощью функции:

# %%
fill_between(x,  y1,  y2=0,  where=None,  interpolate=False,  step=None,  *, data=None, **kwargs)

# %% [markdown]
# Основные параметры здесь следующие:
#
# * x, y1 – массивы значений координат x и функции y1;
# * y2 – массив (или число) для второй кривой, до которой производится заливка;
# * where – массив булевых элементов, который определяет области для заливки.
#
# В самом простом случае эту функцию можно использовать так:

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
plt.plot(x, y)
plt.fill_between(x, y)

# %% [markdown]
# У нас получилась косинусоида с заливкой между значениями функции y и осью абсцисс y2 = 0. Если третьим параметром указать другое число, отличное от нуля, например, 0,5:

# %%
plt.fill_between(x, y, 0.5)

# %% [markdown]
# А если дополнительно еще сделать ограничение на выбор заливаемого региона, когда y < 0:

# %%
plt.fill_between(x, y, 0.5, where=(y < 0))

# %% [markdown]
# Также можно вызвать эту функцию два раза подряд

# %%
plt.fill_between(x, y, where=(y < 0), color='r', alpha=0.5)
plt.fill_between(x, y, where=(y > 0), color='g', alpha=0.5)

# %% [markdown]
# Вот так можно с помощью функции plot() отображать графики в координатных осях и делать их простое оформление.

# %% [markdown]
# ## 3. Отображение нескольких координатных осей в одном окне

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Функция subplot()

# %% [markdown]
# Частой задачей является отображение нескольких координатных осей (Axes) в одном окне (Figure). В самом простом варианте это можно сделать с помощью функции **subplot**, которая имеет следующий синтаксис:

# %%
subplot(nrows, ncols, index)

# %% [markdown]
# где nrows, ncols – число строк и столбцов; index – индекс текущих координатных осей. Например, мы можем разбить все пространство окна на одну строку и три столбца, получим 1 x 3 = 3 поля для отображения графиков:

# %%
plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))

plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))

plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))

plt.grid() # сетка отображается только на последнем графике

# %% [markdown]
# Обратите внимание, что сетка отобразилась только для последнего графика. Почему так произошло? Дело в том, что функция **grid()** сработала для активного объекта Axes. А это был, как раз, третий график. Соответственно, если мы хотим установить сетку для всех осей, то, конечно, можно прописать **grid()** после каждого вызова функции **subplot()**:

# %%
plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
plt.grid()

plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))
plt.grid()

plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))
plt.grid()

# %% [markdown]
# Но можно применить более гибкий способ, сохраняя ссылки на каждую из осей в отдельной переменной:

# %%
ax1 = plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))

ax2 = plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))

ax3 = plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))

ax1.grid()
ax2.grid()
ax3.grid()

# %% [markdown]
# То есть, каждый вызов функции **subplot()** возвращает ссылку на создаваемый объект Axes. Причем, он создается именно в этот момент и не раньше. Например, если не создавать оси с индексом 2, то в окне будут только два графика. Или, можно сделать так. Разбить все окно на сетку 2 x 3 и во второй строке разместить один общий график:

# %%
ax1 = plt.subplot(2, 3, 1)
plt.plot(np.random.random(10))

ax2 = plt.subplot(2, 3, 2)
plt.plot(np.random.random(10))

ax3 = plt.subplot(2, 3, 3)
plt.plot(np.random.random(10))

ax4 = plt.subplot(2, 1, 2)
plt.plot(np.random.random(10))

# %% [markdown]
# Работает это так. Разбиение subplot(2, 3, x) дает две строки и три столбца. Соответственно, в первой строке мы размещаем три графика. Далее, выбираем разбиение тоже в две строки, но один столбец – subplot(2, 1, x). Это позволяет нам сформировать единый график во второй строке, указывая индекс 2

# %% [markdown]
# Вот так гибко можно оперировать расположениями полей для графиков. Причем, если число:
#
#     nrows < 10 и ncols < 10
#
# то вместо трех чисел можно указывать одно трехзначное число:

# %%
ax1 = plt.subplot(131)
plt.plot(np.random.random(10))

ax2 = plt.subplot(132)
plt.plot(np.random.random(10))

ax3 = plt.subplot(133)
plt.plot(np.random.random(10))

# %% [markdown]
# ### Функция subplots()

# %% [markdown]
# Однако, с помощью функции **subplot()** не очень удобно оперировать большим числом координатных осей в пределах одной формы. Для этого лучше подходит другая похожая функция:

# %%
subplots(nrows, ncols)

# %% [markdown]
# которая на выходе дает ссылку на фигуру и список координатных осей:

# %%
plt.subplots(2, 2)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %% [markdown]
# Причем, оси здесь создаются сразу в отличие от функции **subplot()**. Далее, мы можем взять любой объект Axes, чтобы работать с нужным нам полем, например, так:

# %%
f, ax = plt.subplots(2, 2)

ax[0, 0].plot(np.random.random(5))
ax[0, 0].grid()

ax[1, 1].plot(np.random.random(5))
ax[1, 1].grid()

# %% [markdown]
# ### Объект Figure

# %% [markdown]
# Мало того, используя ссылку на объект **Figure**, можно устанавливать те или иные свойства для всего окна:

# %%
f, ax = plt.subplots(2, 2)

f.set_size_inches(10, 5) # размер 10 х 5 дюймов
f.set_facecolor('#eee') # цвет фона (светло-серый)

# %% [markdown]
# Объект **Figure** можно создавать и независимо с помощью класса Figure, например, так:

# %%
fig = plt.figure(figsize=(4, 4))
plt.plot(np.arange(0, 5, 0.2))

# %% [markdown]
# Можно отдельно создать координатную ось и, затем, в ней отображать графики:

# %%
fig = plt.figure(figsize=(3, 3))
ax1 = fig.add_axes([0, 0, 1.0, 1.0])
ax1.plot(np.arange(0, 5, 0.2))

# %% [markdown]
# Здесь список параметров в методе add_axes() следует интерпретировать как **[pos_x, pos_y, width, height]**

# %% [markdown]
# Причем, все значения определяются в интервале [0; 1] и, фактически определяют долю от ширины или высоты окна. В данном случае оси занимают все пространство окна. То есть, с помощью метода add_axes() можно располагать координатные оси совершенно произвольным образом.

# %% [markdown]
# ### Компоновка графиков с помощью GridSpec

# %% [markdown]
# Рассмотренные ранее подходы к компоновке графиков хороши при размещении графиков в ячейках регулярной сетки. Для более сложных элементов компоновки хорошо подходит класс GridSpec из ветки **matplotlib.gridspec**

# %% [markdown]
# То есть, вначале его нужно импортировать, например, так:

# %%
from matplotlib.gridspec import GridSpec

# %% [markdown]
# Далее, с его помощью мы также разбиваем все пространство фигуры на строки и столбцы:

# %%
fig = plt.figure(figsize=(5, 5))
gs = GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = plt.subplot(gs[0, 0])
ax1.plot(np.arange(0, 5, 0.2))

ax2 = fig.add_subplot(gs[1, 0:2])
ax2.plot(np.random.random(10))

ax3 = fig.add_subplot(gs[:, 2])
ax3.plot(np.random.random(10))

# %% [markdown]
# ## 4. Граничные значения осей и локаторы для расположения меток на них

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Граничные значения осей

# %% [markdown]
# При отображении графиков граничные значения по каждой из осей по умолчанию определяются автоматически, исходя из набора отображаемых данных. Однако, иногда требуется указывать свои лимитные значения. Для существующих осей (после их создания) настройка граничных значений производится с помощью метода **set**, следующим образом:

# %%
ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

# %%
fig = plt.figure(figsize=(5, 4)) # создаем окно
ax = fig.add_subplot() # добавляем оси
ax.plot(np.arange(1, 5, 0.25))

# %% [markdown]
# Меняем значения осей:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))

ax.set(xlim=(0, 3), ylim=(0, 2))
# Out:
# [(0.0, 3.0), (0.0, 2.0)]

# %% [markdown]
# Ту же самую операцию можно выполнить и с помощью методов:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))

ax.set_xlim(0, 3)
ax.set_ylim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# Ещё один способ с явным указанием параметров:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))

ax.set_xlim(xmin = 0, xmax=3)
ax.set_ylim(ymin=0, ymax=2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# ### Положение меток на координатных осях

# %% [markdown]
# Пакет matplotlib по умолчанию довольно хорошо расставляет метки сетки при отображении графиков. Но если требуется их изменить, то мы легко можем это делать с помощью двух специальных методов:
#
# * **set_major_locator()** – управление рисками крупной сетки;
# * **set_minor_locator()** – управление рисками мелкой сетки.
#
# В качестве аргумента они принимают экземпляр класса, унаследованный от базового класса - **matplotlib.ticker.Locator**

# %% [markdown]
# #### NullLocator

# %% [markdown]
# Давайте воспользуемся самым простым производным классом **NullLocator**, который используется для сокрытия меток по выбранной оси. Вначале его нужно импортировать:

# %%
from matplotlib.ticker import NullLocator

# %% [markdown]
# Создать экземпляр и указать в качестве параметра у оси Ox или Oy:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))

lc = NullLocator()
ax.grid()
ax.xaxis.set_major_locator(lc) # скрывем метки и сетку по оси X

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))

lc = NullLocator()
ax.grid()
ax.yaxis.set_major_locator(lc) # скрывем метки и сетку по оси Y

# %% [markdown]
# #### LinearLocator

# %%
from matplotlib.ticker import LinearLocator

# %% [markdown]
# Следующий класс LinearLocator используется для задания нужного числа меток по выбранной оси графика. Например, вот так можно задать ровно пять рисок по оси Oy:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))
ax.grid()

ax.yaxis.set_major_locator(LinearLocator(5))

# %% [markdown]
# Как видите, числа по вертикали получились не очень наглядными и работать с такой сеткой было бы проблематично. Это один из главных недостатков этого локатора. Поэтому его редко применяют на практике.

# %% [markdown]
# #### MultipleLocator

# %% [markdown]
# Следующий класс MultipleLocator позволяет задавать шаг изменения значений между соседними рисками. Для этого используется единственный параметр base этого класса, который и определяет шаг следования значений в соответствии с формулой:
#
#                                     base ∙ i, где  i = ±1, ±2, ...

# %%
from matplotlib.ticker import MultipleLocator

# %% [markdown]
# Например, укажем шаг изменения по оси Ox, равным 1:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot() 
ax.plot(np.arange(1, 5, 0.25))
ax.grid()

ax.xaxis.set_major_locator(MultipleLocator(base=3))

# %% [markdown]
# #### IndexLocator

# %% [markdown]
# Следующий класс IndexLocator работает аналогичным образом, что и класс MultipleLocator, но производит отсчет значений рисок не от 0, а от наименьшего значения данных графика. В конструкторе класса IndexLocator определены два параметра:
#
# * base – шаг изменения между соседними рисками;
# * offset – смещение относительно наименьшего значения.

# %%
from matplotlib.ticker import IndexLocator

# %% [markdown]
# Например, сформируем график синусоиды и по оси Ox отложим метки с помощью IndexLocator с шагом 0,5 и нулевым смещением:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()
ax.xaxis.set_major_locator(IndexLocator(base=0.5, offset=0))

# %% [markdown]
# #### FixedLocator

# %%
from matplotlib.ticker import FixedLocator

# %% [markdown]
# Это очень простой класс локатора, который устанавливает метки в указанных значениях. Например, так:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
ax.plot(np.random.random(10))

ax.xaxis.set_major_locator(FixedLocator([2, 5, 8, 9]))

# %% [markdown]
# #### LogLocator

# %%
from matplotlib.ticker import LogLocator

# %% [markdown]
# Для формирования логарифмических делений по осям используется класс LogLocator. Его параметр base определяет число, которое будет возводиться в степень чисел:
#
#                                                     base ^ i,  i = 0, 1, 2, …
#
# По умолчанию используется base=10, но мы можем поменять основание и указать любое другое, например, два:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
ax.plot(np.random.random(10))

ax.xaxis.set_major_locator(LogLocator(base=2))

# %% [markdown]
# #### MaxNLocator

# %%
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# Следующий локатор выполняет самостоятельную разбивку интервала на число рисок не более значения nbins, указанного при создании его экземпляра. В самом простом варианте мы можем создать объект этого локатора без указания максимального числа рисок:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
ax.plot(np.random.random(10))

ax.xaxis.set_major_locator(MaxNLocator(nbins=4))

# %% [markdown]
# Локатор создал разбиение с четырьмя рисками. То есть, он решил, что такое разбиение будет наиболее понятным, т.к. значения рисок принимают «красивые» значения и с ними будет легко работать конечному пользователю. В общем, в этом и заключается цель этого локатора. Более подробную информацию можно почитать на странице официальной документации

# %% [markdown]
# ### Использование функции set_minor_locator()

# %% [markdown]
# Все те же самые действия можно выполнять и с мелкой (минорной) сеткой. Для этого ее нужно сначала включить и показать на графике:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
ax.plot(np.random.random(10))

ax.minorticks_on()
ax.grid(which='major', lw = 2) 
ax.grid(which='minor')

# %% [markdown]
# Здесь параметр which функции grid() как раз указывает какую сетку показать. По умолчанию включается только крупная сетка. Однако, использовать всегда еще и мелкую не лучший шаг, так как это требует дополнительных вычислительных ресурсов. Поэтому, чаще всего, используется только крупная сетка.
#
# После того, как мы включили минорную сетку, то для нее с помощью функции set_minor_locator() можно также задавать различные локаторы, например, NullLocator:

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot()
ax.plot(np.random.random(10))

ax.minorticks_on()
ax.grid(which='major', lw = 2) 
ax.grid(which='minor')

ax.xaxis.set_minor_locator(NullLocator())

# %% [markdown]
# ## 5. Настраиваем формат отображения меток у координатных осей

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Помимо управления расположения меток на координатных осях можно также задавать формат вывода информации. Для этого используются различные форматеры. Но, прежде чем мы перейдем к их рассмотрению, отмечу две довольно распространенные на практике функции, с помощью которых часто делают сокрытие текстовых меток для тиков графика:

# %% [markdown]
# **set_xticklabels(), set_yticklabels()**

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.set_xticklabels([])
ax.set_yticklabels([])

ax.grid()

# %% [markdown]
# Если же требуется более тонкая настройка формата тиков, то для этого в matplotlib используется функция **set_major_formatter()**, которая применяет тот или иной форматер для форматирования текстовой информации у соответствующих координатных осей.

# %% [markdown]
# Само форматирование осуществляется с помощью различных классов, расположенных в ветке: **matplotlib.ticker**

# %% [markdown]
# ### NullFormatter

# %% [markdown]
# В самом простом варианте используется класс **NullFormatter**, который позволяет отключать надписи под рисками у выбранной оси. Вначале нам нужно его импортировать:

# %%
from matplotlib.ticker import NullFormatter

# %% [markdown]
# А, затем, применить к оси абсцисс или ординат:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.xaxis.set_major_formatter(NullFormatter())

# %% [markdown]
# Мы здесь сначала обращаемся к объекту xaxis, отвечающий за ось Ox, и вызываем функцию **set_major_formatter()**, передавая ей экземпляр класса NullFormatter. В результате, подписи у этой оси исчезают и мы видим результат.

# %% [markdown]
# По аналогии, можно работать и с осью ординат, только для этого следует использовать объект yaxis:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.yaxis.set_major_formatter(NullFormatter())

# %% [markdown]
# ### FormatStrFormatter

# %%
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# Следующий класс FormatStrFormatter позволяет устанавливать формат числовых данных подписей рисок. Для этого в конструктор данного класса передается спецификатор числа нужного формата, например, запись будет округлять все числа до целых и по оси Oy мы увидим следующее:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.yaxis.set_major_formatter(FormatStrFormatter('%d'))

# %% [markdown]
# Если же указать спецификатор в виде %f, то получим вещественные числа с шестью знаками после запятой:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.yaxis.set_major_formatter(FormatStrFormatter('%f'))

# %% [markdown]
# Для управления точностью вещественных чисел используется запись вида:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

# %% [markdown]
# ### FuncFormatter

# %%
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# Если у нас имеется некий алгоритм формирования надписей для рисок, то здесь хорошо подойдет класс FuncFormatter, формирующий значения на основе заданной функции. Например, зададим функцию, которая отрицательные значения будет заключать в квадратные скобки, а положительные – в круглые:

# %%
def formatOy(x, pos):
    return f"[{x}]" if x < 0 else f"({x})"


fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))
ax.grid()

ax.yaxis.set_major_formatter(FuncFormatter(formatOy))

# %% [markdown]
# ### ScalarFormatter

# %%
from matplotlib.ticker import ScalarFormatter

# %% [markdown]
# Этот форматер используется пакетом matplotlib по умолчанию. Он отображает числовые данные так, как они есть с небольшими манипуляциями. Если число оказывается очень большим (больше 10^10), то его множитель выносится, то же самое происходит и с очень маленькими числами (меньше 10^-10). Но мы можем изменить это поведение и настроить свой диапазон больших и малых значений. Например, если вывести график в диапазоне степени 10^5:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
ax.plot(x, np.sinc(x) * 1e5)

sf = ScalarFormatter()
sf.set_powerlimits((-4, 4))
ax.yaxis.set_major_formatter(sf)

ax.grid()

# %% [markdown]
# ### FixedFormatter

# %%
from matplotlib.ticker import FixedFormatter

# %% [markdown]
# Если каждой риске оси нужно присвоить строго определенное значение, то для этого хорошо подходит класс FixedFormatter. Работает он очень просто. Его конструктору передается список значений, которые, затем, будут подставлены соответствующим рискам. Например:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
ax.plot(x, np.sinc(x) * 1e5)

ax.xaxis.set_major_locator(FixedLocator([-3, -2, -1, 0, 1, 2, 3]))
ax.xaxis.set_major_formatter(FixedFormatter(['a', 'b', 'c', 'd', 'e', 'f', 'g']))

ax.grid()

# %% [markdown]
# Причем, обратите внимание, мы использовали класс FixedFormatter совместно с классом FixedLocator, так как желательно, чтобы списки по длинам в этих классах совпадали.

# %% [markdown]
# ## 6. Делаем логарифмический масштаб у координатных осей

# %% [markdown]
# До сих пор мы с вами отображали графики в декартовой системе с линейным шагом изменения значений. Это довольно частый вариант, который используется в большинстве случаев. Но бывают функции, которые требуют логарифмического масштаба (изменения шага) по координатам.

# %% [markdown]
# ![](https://proproprogs.ru/htm/modules/files/matplotlib-delaem-logarifmicheskiy-masshtab-u-koordinatnyh-osey.files/image001.jpg)

# %% [markdown]
# Например, если сформировать график функции:

# %% [markdown]
# ![](https://proproprogs.ru/htm/modules/files/matplotlib-delaem-logarifmicheskiy-masshtab-u-koordinatnyh-osey.files/image002.png)

# %% [markdown]
# Если отобразить его в линейной системе координат, то мелкие колебания функции на больших частотах будут не видны:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
 
x = np.arange(-10*np.pi, 10*np.pi, 0.5)
ax.plot(x, np.sinc(x) * np.exp( -np.abs(x/10)) )

ax.grid()

# %% [markdown]
# Как раз здесь может помочь логарифмический масштаб по оси ординат. Для этого достаточно воспользоваться методом **semilogy()**, чтобы по оси Oy откладывался логарифмический масштаб (логарифм по основанию 10) для графика:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
 
x = np.arange(-10*np.pi, 10*np.pi, 0.5)

ax.plot(x, np.sinc(x) * np.exp( -np.abs(x/10)) )
ax.grid()
ax.semilogy(x, np.sinc(x) * np.exp( -np.abs(x/10)) )

# %% [markdown]
# Видите, стало гораздо информативнее и конечному пользователю показывается больше информации о сигнале.

# %% [markdown]
# Аналогично, можно формировать логарифмический масштаб по оси ординат с помощью метода **semilogx()**

# %% [markdown]
# Того же самого эффекта можно добиться и с помощью прежней функции **plot()**, только дополнительно указать логарифмический масштаб по нужной оси. Например, так:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
 
x = np.arange(-10*np.pi, 10*np.pi, 0.5)

ax.plot(x, np.sinc(x) * np.exp( -np.abs(x/10)) )
ax.grid()

ax.set_yscale('log')

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
 
x = np.arange(-10*np.pi, 10*np.pi, 0.5)

ax.plot(x, np.sinc(x) * np.exp( -np.abs(x/10)) )
ax.grid()

ax.set_xscale('log')

# %% [markdown]
# ## 7. Размещаем стандартные текстовые элементы на графике

# %% [markdown]
# ### Размещение мажорной и минорной сетки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# На одном из прошлых занятий мы увидели, как можно строить двумерные линейные графики с помощью функции **plot()** и задавать различные стили его отображения: цвет, тип, толщину линии. На этом занятии продолжим тему оформления графиков и начнем с сетки. Как мы уже говорили, в самом простом случае достаточно вызвать команду **grid()**:

# %%
y = np.arange(0, 5, 1)
x = np.array([a*a for a in y])

y2 = [0, 2, 3, 4, 5, 7]
x2 = [i+1 for i in y2]

lines = plt.plot(x, y, x2, y2)
plt.grid()

# %% [markdown]
# Помимо обычной крупной сетки (major grid) можно наложить более мелкую (minor grid) минорную сетку. Для этого сначала нужно включить режим отображения минорной сетки, а, затем, в функции grid() прописать два типа сеток (мажорную и минорную):

# %%
y = np.arange(0, 5, 1)
x = np.array([a*a for a in y])

y2 = [0, 2, 3, 4, 5, 7]
x2 = [i+1 for i in y2]

lines = plt.plot(x, y, x2, y2)

plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 1)
plt.grid(which='minor', color='#aaa', ls=':')

# %% [markdown]
# Однако, здесь следует иметь в виду, что такая мелкая сетка заметно снижает производительность при отображении графиков. Поэтому без особой необходимости ее лучше не использовать.

# %% [markdown]
# ### Создание надписей и подписей

# %% [markdown]
# У каждой оси (объекта Axes) можно определять следующие текстовые элементы:
#
# * title – заголовок для осей;
# * xlabel, ylabel – подписи для каждой из осей;
# * text – произвольная текстовая информация в области осей;
# * annotate – аннотация (текст с указателем).
#
# Также, у окна в целом можно задавать такие текстовые элементы:
#
# * subtitle – заголовок для фигуры (окна);
# * figtext – размещение произвольной текстовой информации в области окна.
#
# Давайте в качестве примера посмотрим, как работают все эти элементы на графике:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

plt.figtext(0.15, 0.8, 'Текст в области окна')
fig.suptitle('Заголовок окна')
ax.set_xlabel('Ox')
ax.set_ylabel('Oy')
 
ax.text(0.1, 0.1, 'Произвольный текст в координатных осях')
ax.annotate('Аннотация', xy=(0.2, 0.4), xytext=(0.6, 0.7),
            arrowprops={'facecolor': 'gray', 'shrink': 0.1})
# Out:
# Text(0.6, 0.7, 'Аннотация')

# %% [markdown]
# ### Оформление текстовых элементов

# %% [markdown]
# Теперь перейдем к оформлению на уровне текстовых блоков. Как правило, все текстовые элементы в **matplotlib** – это объекты класса **Text**. И у них имеются стандартный набор свойств для их оформления. Полный их перечень можно посмотреть на странице официальной документации.

# %% [markdown]
# **Наиболее употребительные:**

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120042.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120042.png)

# %% [markdown]
# **Примеры использования:**

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

plt.figtext(0.15, 0.8, 'Текст в области окна', style='italic', fontsize=15)
fig.suptitle('Заголовок окна', color='blue')
ax.set_xlabel('Ox', color='red')
ax.set_ylabel('Oy', color='red')
 
ax.text(0.1, 0.1, 'Произвольный текст в координатных осях')
ax.annotate('Аннотация', xy=(0.2, 0.4), xytext=(0.6, 0.7),
            arrowprops={'facecolor': 'gray', 'shrink': 0.1})
# Out:
# Text(0.6, 0.7, 'Аннотация')

# %% [markdown]
# ### Параметр bbox

# %% [markdown]
# С помощью параметра bbox можно устанавливать дополнительные элементы оформления для текстовых блоков. Ему следует указать словарь, ключами которого являются аргументы класса **FancyBboxPatch**:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120328.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120328.png)

# %% [markdown]
# В качестве параметра boxstyle можно выбирать следующие значения:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120359.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20120359.png)

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
 
ax.text(15, 2, 'Текст', bbox={'boxstyle':'darrow', 'facecolor': '#AAAAFF'})
ax.plot(np.arange(0, 5, 0.25))

# %% [markdown]
# ### Цвет фона фигуры и координатных осей

# %% [markdown]
# Используя параметр **facecolor** можно задавать цвет фона для всей формы и отдельно для координатных осей. Например, если при создании фигуры указать этот параметр в виде:

# %%
fig = plt.figure(figsize=(7, 4), facecolor='pink')
ax = fig.add_subplot(facecolor='azure')
ax.plot(np.arange(0, 5, 0.25), color='black')

# %% [markdown]
# Или, это можно сделать с помощью метода **set()** после создания фигуры:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(0, 5, 0.25))

fig.set(facecolor='pink')
ax.set(facecolor='azure')
# Out:
# [None]

# %% [markdown]
# ## 8. Добавляем легенду и рисуем геометрические фигуры на графиках

# %% [markdown]
# Давайте предположим, что в наших координатных осях показаны два графика, если мы теперь попытаемся отобразить легенду – их краткое описание, с помощью метода **ax.legend()**, то увидим пустой квадратик в верхнем левом углу. Почему в нем ничего нет?

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25))
ax.plot(np.arange(0, 10, 0.5))

ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Дело в том, что нам нужно для каждой линии (графика) добавить символьное имя. Это делается с помощью именованного параметра **label**:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25), 'r-o',label='line1')
ax.plot(np.arange(0, 10, 0.5), 'b:', label='line2')

ax.legend()

# %% [markdown]
# Также мы можем самостоятельно указывать метки линий при отображении легенды. Для этого достаточно передать список меток в метод **legend()**:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25), 'r-o',label='line1')
ax.plot(np.arange(0, 10, 0.5), 'b:', label='line2')

ax.legend(['Hello', 'World'])

# %% [markdown]
# Далее, с помощью параметра **loc** можно указывать расположение окна легенды в пределах координатных осей. Этот параметр может принимать следующие значения:

# %%
['best', 'upper right', 'upper left', 'lower left', 'lower right', 
 'right', 'center left', 'center right', 'lower center', 'upper center', 'center']

# %% [markdown]
# Названия здесь говорят сами за себя. Например, можно записать:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25), 'r-o',label='line1')
ax.plot(np.arange(0, 10, 0.5), 'b:', label='line2')

ax.legend(['Hello', 'World'], loc='lower right')

# %% [markdown]
# Если требуется более точное указание местоположения легенды, то можно воспользоваться параметром **bbox_to_anchor** и указать координаты информационного окна:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25), 'r-o',label='line1')
ax.plot(np.arange(0, 10, 0.5), 'b:', label='line2')

ax.legend(['Hello', 'World'], bbox_to_anchor=(0.5, 0.7))

# %% [markdown]
# Наконец, для оформления информации в окне легенды можно использовать следующие параметры:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20122821.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20122821.png)

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

ax.plot(np.arange(0, 5, 0.25), 'r-o',label='line1')
ax.plot(np.arange(0, 10, 0.5), 'b:', label='line2')

ax.legend(['line1', 'line2'], bbox_to_anchor=(0.5, 0.6), facecolor='#aaa', framealpha=0.5)

# %% [markdown]
# ### Рисование геометрических фигур на графике

# %% [markdown]
# Пакет matplotlib позволяет рисовать произвольные фигуры прямо в координатных осях. Это очень удобно, когда нужно добавить нестандартную графическую информацию к отображаемому графику.

# %% [markdown]
# Более подробная информация по ссылке:

# %% [markdown]
# https://proproprogs.ru/modules/matplotlib-dobavlyaem-legendu-i-risuem-geometricheskie-figury-na-grafikah

# %% [markdown]
# ## 9. Рисуем ступенчатые, стековые, stem и точечные графики

# %% [markdown]
# До сих пор мы с вами рассматривали построение и оформление простого двумерного графика, в основном, с помощью функции plot(). Вместе с тем, пакет matplotlib поддерживает большое разнообразие других типов графиков, и с некоторыми из них мы сейчас познакомимся.

# %% [markdown]
# ### Ступенчатый (step) график

# %% [markdown]
# В самом простом случае ступенчатый график строится с помощью функции **step()**, следующим образом:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()
 
x = np.arange(0, 10)
ax.step(x, x)
ax.grid()

# %% [markdown]
# Обратите внимание, мы здесь обязательно должны передать список и для координаты x и для координаты y. Передавать только значения для y, как это было в функции **plot()**, нельзя.
#
# В чем ценность такого графика? В научной литературе он используется для отображения изменения цифровых данных, когда каждое значение имеет строго определенный уровень. При этом, промежуточных уровней между соседними цифровыми значениями не существует. Поэтому, правильно такие данные отображать в виде ступенчатого графика. А не линейного, который, как бы намекает, что реальные данные могут быть линейно интерполированы между соседними отсчетами.
#
# Оформление ступенчатого графика выполняется также, как и для линейного. Например, можно указать тип, цвет и маркеры в следующем виде:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()
 
x = np.arange(0, 10)
ax.step(x, x, 'b--o', where='post')
ax.grid()

# %% [markdown]
# ### Стековый график

# %% [markdown]
# Если нам нужно отобразить несколько наборов данных:
#
#                         y1, y2, y3, …,
#
# в виде стека (друг над другом), причем каждый следующий график является суммой предыдущих и самого себя, то для этого можно воспользоваться функцией **stackplot()**:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-2, 2, 0.1)
y1 = np.array([-y**2 for y in x]) + 8
y2 = np.array([-y**2 for y in x]) + 8
y3 = np.array([-y**2 for y in x]) + 8

ax.stackplot(x, y1, y2, y3)

# %% [markdown]
# ### Stem-график

# %% [markdown]
# Если нам нужно отобразить данные в виде отдельных точек, соединенных линией с некоторым базовым уровнем, то можно воспользоваться функцией **stem()**:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi, np.pi, 0.3)
ax.stem(x, np.cos(x))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# По умолчанию уровень базовой линии находится в нуле. Но мы можем его изменить, указав значение через параметр **bottom**:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

ax.stem(x, np.cos(x), bottom=0.5)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# В качестве маркеров можно использовать следующие символы:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20125600.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20125600.png)

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

ax.stem(x, np.cos(x), 'b--o', '^r', bottom=0.5)
# Out:
# C:\Users\Vadim\AppData\Local\Temp\ipykernel_12112\1647926634.py:4: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   ax.stem(x, np.cos(x), 'b--o', '^r', bottom=0.5)
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Точечный график

# %% [markdown]
# Следующий интересный график – это отображение данных в виде набора точек. Например, такая визуализация используется для получения картины разброса случайных данных (величин). Предположим, генерируем 500 нормальных случайных величин для осей x и y:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.random.normal(0, 2, 500)
y = np.random.normal(0, 2, 500)

ax.scatter(x, y)

# %% [markdown]
# У этой функции имеются дополнительные параметры для визуальной настройки формируемого графика:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20125845.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20125845.png)

# %% [markdown]
# Например, можно сформировать вот такой вид этого графика:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.random.normal(0, 2, 500)
y = np.random.normal(0, 2, 500)

ax.scatter(x, y, color='black', alpha=0.5)

# %% [markdown]
# Все рассмотренные типы графиков на этом занятии:
#
# * ступенчатый (stem);
# * стековый (stackplot);
# * stem-график;
# * точечный (scatter)
#
# можно оформлять по аналогии с графиком **plot()**, о котором мы говорили на предыдущих занятиях. Также добавлять различные надписи, работать с сеткой, задавать типы координатных осей, делать визуальное оформление и т.п. На следующем занятии мы продолжим эту тему и рассмотрим построение гистограмм, столбчатых и круговых диаграмм.

# %% [markdown]
# ## 10. Рисуем гистограммы, столбчатые и круговые диаграммы

# %% [markdown]
# На этом занятии мы продолжим знакомство с разными типами двумерных графиков и увидим, как можно строить столбчатые и круговые диаграммы.

# %% [markdown]
# ### Гистограмма и столбчатые диаграммы

# %% [markdown]
# #### Функция hist

# %% [markdown]
# Иногда данные требуется сгруппировать по определенным диапазонам и подсчитать сколько значений попадает в тот или иной интервал. Для выполнения такой задачи хорошо подходят столбчатые диаграммы и довольно известный их вид – это гистограмма распределения случайной величины.
#
# Давайте сгенерируем вектор из 500 случайных величин и выведем их в виде гистограммы, используя функцию **hist()**:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()
 
y = np.random.normal(0, 2, 500)

ax.hist(y)
ax.grid()

# %% [markdown]
# Фактически, мы здесь имеем набор столбиков, высота которых определяется числом СВ, попавших в тот или иной диапазон. Причем, по умолчанию функция **hist()** разбивает весь интервал на равных 10 диапазонов. Если требуется изменить это число, то мы можем его указать вторым параметром:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()
 
y = np.random.normal(0, 2, 500)

ax.hist(y, 50)
ax.grid()

# %% [markdown]
# #### Функции bar() и barh()

# %% [markdown]
# Похожий график можно сформировать и с помощью функции **bar**. Ей на вход, в самом простом варианте, нужно передать список отметок для столбцов x и значения высот каждого столбца y:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

x = [f'H{i+1}' for i in range(10)]
y = np.random.randint(1, 5, len(x))

ax.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Если нам нужно отображать столбики относительно оси ординат, то для этого существует функция **barh()**, которая работает аналогично функции **bar()**:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

x = [f'H{i+1}' for i in range(10)]
y = np.random.randint(300, 500, len(x))

ax.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Функции **bar() и barh()** содержат ряд полезных параметров:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20131902.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20131902.png)

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

x = [f'H{i+1}' for i in range(10)]
y = np.random.randint(-20, 20, len(x))

ax.bar(x, y, bottom=10, color='blue', edgecolor='black', linewidth=2)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Благодаря использованию параметра **width** мы легко можем формировать групповые столбчатые диаграммы, следующим образом:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

x = np.arange(10)
y1 = np.random.randint(3, 20, len(x))
y2 = np.random.randint(3, 20, len(x))
w = 0.3

ax.bar(x - w/2, y1, width=w)
ax.bar(x + w/2, y2, width=w)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Здесь правые столбцы сдвинуты вправо на половину своей толщины, а левые – влево на половину той же ширины. В итоге, получаем такое наглядное групповое изображение столбиков.

# %% [markdown]
# ### Круговые диаграммы

# %% [markdown]
# Иногда вместо столбцов нам нужно наглядно изобразить доли чего-либо в виде круговой диаграммы. Для этого используется функция **pie()**, например, следующим образом:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

vals = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
ax.pie(vals, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2df7f30a740>,
# ...
#  [Text(1.0554422683381766, 0.30990582150899426, 'Toyota'),
#   Text(-0.15654637770487634, 1.0888035780743386, 'BMW'),
#   Text(-1.0250504052974734, -0.3990885448111559, 'Lexus'),
#   Text(0.33991877217145827, -1.046162142464278, 'Audi'),
#   Text(1.0780908383980825, -0.21844940870169383, 'Lada')])

# %% [markdown]
# Эта функция имеет ряд полезных параметров:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20132603.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-07%20132603.png)

# %% [markdown]
# Например, можно выполнить следующие манипуляции с круговой диаграммой, используя эти параметры:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

vals = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
ax.pie(vals, labels=labels, explode=(0.1, 0.2, 0.2, 0, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x2df0304ef80>,
# ...
#  [Text(1.151391565459829, 0.3380790780098119, 'Toyota'),
#   Text(-0.1850093554693993, 1.2867678649969456, 'BMW'),
#   Text(-1.2114232062606503, -0.4716500984131843, 'Lexus'),
#   Text(0.33991877217145827, -1.046162142464278, 'Audi'),
#   Text(1.0780908383980825, -0.21844940870169383, 'Lada')])

# %% [markdown]
# Используя словарь **wedgeprops**, можно сформировать диаграмму с пустотой внутри:

# %%
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

vals = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']

ax.pie(vals, labels=labels, wedgeprops=dict(width=0.5))

# %% [markdown]
# Мы здесь указали, что ширина каждого сегмента составляет половину от начальной величины. В результате образуется пустое круговое пространство внутри диаграммы.
#
# Вот так, достаточно просто можно создавать гистограммы, столбчатые и круговые диаграммы.

# %% [markdown]
# ## 11. Показ изображений и цветовых сеток

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# На этом занятии мы увидим, как с помощью **matplotlib** можно выводить изображения и цветовые сетки. Начнем с показа изображений. Для этого в пакете имеется специальная функция **imshow()**, которая на входе ожидает либо двумерный numpy массив, либо PIL-изображение.

# %%
img = Image.open('panda.png')

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()
ax.imshow(img)

# %% [markdown]
# Функция **imshow()** имеет следующие параметры:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-08%20173309.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-08%20173309.png)

# %%
img = Image.open('panda.png')

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()
ax.imshow(img, alpha=0.5)

# %% [markdown]
# ## 12. Как строить трехмерные графики

# %% [markdown]
# Следующим шагом мы с вами рассмотрим возможности построения трехмерных графиков в пакете matplotlib. Такая возможность появилась, начиная с версии 0.99, поэтому убедитесь, что ваш пакет поддерживает трехмерные графики.

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

# %% [markdown]
# После создания координатных осей мы можем в них строить двумерные и трехмерные графики с помощью того же самого набора функций:
#
# * plot() – линейный 2D график в трех измерениях;
# * step() – ступенчатый 2D график в трех измерениях;
# * scatter() – точеный график 3D график.
#
# Также нам становятся доступными следующие дополнительные функции:
#
# * plot_wireframe() – построение каркасной поверхности в 3D;
# * plot_surface() – построение непрерывной 3D поверхности.

# %% [markdown]
# Начнем с самого простого варианта – функции **plot()** для рисования косинусоиды в трех измерениях:

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.linspace(0, 10, 50)
z = np.cos(x)

ax_3d.plot(x, x, z)

ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %% [markdown]
# Но то, что мы получили, это не совсем трехмерный график. Скорее, это двумерная косинусоида в трех измерениях. Давайте построим настоящее трехмерное изображение, например, вот такой функции:

# %% [markdown]
# ![](https://proproprogs.ru/htm/modules/files/matplotlib-kak-stroit-trehmernye-grafiki.files/image003.png)

# %% [markdown]
# Давайте теперь построим полноценный трехмерный график синусоиды на регулярной сетке. Для этого мы сначала сформируем координаты узлов в плоскости xy:

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)


ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')

ax_3d.plot_wireframe(xgrid, ygrid, zgrid)

# %% [markdown]
# Как видите, мы получили полноценный каркасный трехмерный график синусоиды. Или же можно построить полноценную поверхность в виде синусоиды, используя функцию **plot_surface()**:

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)


ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')

ax_3d.plot_surface(xgrid, ygrid, zgrid)

# %% [markdown]
# У этих функций есть следующие параметры для настройки внешнего вида графика:

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-08%20175821.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-08%20175821.png)

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)


ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')

ax_3d.plot_surface(xgrid, ygrid, zgrid, cmap='plasma', rstride=5, cstride=5)

# %% [markdown]
# В заключение этого занятия приведу пример построения этого же графика набором точек, используя функцию **scatter()**:

# %%
fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)


ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')

ax_3d.scatter(xgrid, ygrid, zgrid, s=1, color='g')
